# %%
import numpy as np

# %%
zero_vector = np.zeros(5)
zero_matrix = np.zeros(6).reshape(2,3)
zero_matrix
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
empty_arr = np.empty(4)
empty_arr
# Out:
# array([0.5, 1. , 1.5, 2. ])

# %%
empty_arr = empty_arr.reshape(2,2)

# %%
empty_arr.transpose()
# Out:
# array([[0.5, 1.5],
#        [1. , 2. ]])

# %%
a = [1,2,3]
b = np.array(a)
c = a

# %%
c[0], b[0] = 9,9
print(a,b,c)
# Out:
# [9, 2, 3] [9 2 3] [9, 2, 3]

# %%
np.linspace(0,10,10)
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
a = np.ones((5,5))
a.shape
a.size
# Out:
# 25

# %%
x = 10
np.any([x%i == 0 for i in range(2, x)])
# Out:
# True

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,4,9,16])

# %%
x = np.linspace(-10,10,20)
y = x**3

# %%
plt.plot(x,y)

# %%
x = np.linspace(0,5,6)
y1 = x
y2 = x**2
y3 = x**3

plt.plot(x, y1, "rd-", label="Linear")
plt.plot(x, y2, "bo-", label="Binomial")
plt.plot(x, y3, "go-", label="Trinomial")
# plt.axis([-0.5,6,-0.5,26])
plt.legend(loc="upper left")
# plt.savefig("img.png")

# %%
x = np.random.normal(size=1000)

# %%
plt.hist(x)
# Out:
# (array([ 11.,  41.,  74., 173., 217., 233., 133.,  78.,  28.,  12.]),
#  array([-2.95721897, -2.35939929, -1.7615796 , -1.16375991, -0.56594022,
#          0.03187947,  0.62969915,  1.22751884,  1.82533853,  2.42315822,
#          3.02097791]),
#  <BarContainer object of 10 artists>)

# %%
import random
random.choice(list([1,2,3,4]))
# Out:
# 3

# %%
rolls = []

for i in range(10000):
    a = random.choice(range(7))
    for j in range(10):
        rolls.append(a)
    
plt.hist(rolls, bins=np.linspace(0.5,6.5,7),)
# Out:
# (array([14750., 13870., 13930., 13830., 14430., 14570.]),
#  array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  <BarContainer object of 6 artists>)

# %%
np.random.normal((0,1),1,(2,2))
# Out:
# array([[ 0.65544249, -0.11619043],
#        [-0.05690793,  1.80841488]])

# %%
b = np.array(range(9)).reshape(3,3)

# %%
b[(0,1)]
# Out:
# 1
